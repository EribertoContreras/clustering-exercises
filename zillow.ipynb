# %% [markdown]
# ### Zillow
#     For the following, iterate through the steps you would take to create functions: Write the code to do the following in a jupyter notebook, test it, convert to functions, then create the file to house those functions.
#
#     You will have a zillow.ipynb file and a helper file for each section in the pipeline.
#
#
#
# 1) Acquire and Summarize
#
# - Acquire data from the cloud database.
#
# - You will want to end with a single dataframe. Include the logerror field and all other fields related to the       properties that are available. You will end up using all the tables in the database.
#
# - Be sure to do the correct join (inner, outer, etc.). We do not want to eliminate properties purely because they may have a null value for airconditioningtypeid. - Only include properties with a transaction in 2017, and include only the last transaction for each property (so no duplicate property ID's), along with zestimate error and date of transaction. (Hint: read the docs for the .duplicated method) - Only include properties that have a latitude and longitude value.
#
# 2) Summarize your data (summary stats, info, dtypes, shape, distributions, value_counts, etc.)
#
# 3) Write a function that takes in a dataframe of observations and attributes and returns a dataframe where each row is an atttribute name, the first column is the number of rows with missing values for that attribute, and the second column is percent of total rows that have missing values for that attribute. Run the function and document takeaways from this on how you want to handle missing values.
#
#    The output should look like the table below:
#
#     num_rows_missing	pct_rows_missing
#     parcelid	0	0.000000
#    airconditioningtypeid	29041	0.535486
#    architecturalstyletypeid	54232	0.999982

# %% [markdown]
# ***

# %% [markdown]
# ## 1) Aquiring The Zillow Data Set
# - we will be using the imports from below to work on our data and to retrieve the DataFrame

# %%
# fetches the data
import acquire
# credentials file to access the data
import env
# Imports functions necessary to run visuals and hides unnecessary code
import wrangle_zillow

# coding 
import math
import numpy as np
import seaborn as sns
import scipy.stats as stats
import pandas as pd
import matplotlib.pyplot as plt
from pydataset import data
import scipy.stats
import scipy
import os

# needed for modeling
import sklearn.preprocessing
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import MinMaxScaler, StandardScaler, RobustScaler, QuantileTransformer
from sklearn.metrics import explained_variance_score
import statsmodels.api as sm
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import LinearRegression, LassoLars, TweedieRegressor
from sklearn.preprocessing import PolynomialFeatures

# %% [markdown]
# - Using import file [acquire.py](https://github.com/EribertoContreras/clustering-exercises/blob/main/acquire.py)

# %%
df = acquire.get_zillow_data()

# %% [markdown]
# ***

# %% [markdown]
# ## 2) Summarize
# - using function named summarize(df) from [imports](https://github.com/EribertoContreras/clustering-exercises/blob/main/imports.py)

# %%
wrangle_zillow.summarize(df)
# Out:
# --- Shape: (52442, 69)
# --- Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52442 entries, 0 to 52441
# Data columns (total 69 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   propertylandusetypeid         52442 non-null  float64
#  1   parcelid                      52442 non-null  int64
#  2   storytypeid                   47 non-null     float64
#  3   typeconstructiontypeid        76 non-null     float64
#  4   heatingorsystemtypeid         33936 non-null  float64
#  5   buildingclasstypeid           0 non-null      float64
#  6   architecturalstyletypeid      70 non-null     float64
#  7   airconditioningtypeid         13638 non-null  float64
#  8   id                            52442 non-null  int64
#  9   basementsqft                  47 non-null     float64
#  10  bathroomcnt                   52442 non-null  float64
#  11  bedroomcnt                    52442 non-null  float64
#  12  buildingqualitytypeid         33741 non-null  float64
#  13  calculatedbathnbr             52305 non-null  float64
#  14  decktypeid                    389 non-null    float64
#  15  finishedfloor1squarefeet      4381 non-null   float64
#  16  calculatedfinishedsquarefeet  52360 non-null  float64
#  17  finishedsquarefeet12          52195 non-null  float64
#  18  finishedsquarefeet13          0 non-null      float64
#  19  finishedsquarefeet15          0 non-null      float64
#  20  finishedsquarefeet50          4381 non-null   float64
#  21  finishedsquarefeet6           165 non-null    float64
#  22  fips                          52442 non-null  float64
#  23  fireplacecnt                  7243 non-null   float64
#  24  fullbathcnt                   52305 non-null  float64
#  25  garagecarcnt                  18015 non-null  float64
#  26  garagetotalsqft               18015 non-null  float64
#  27  hashottuborspa                1515 non-null   float64
#  28  latitude                      52442 non-null  float64
#  29  longitude                     52442 non-null  float64
#  30  lotsizesquarefeet             52073 non-null  float64
#  31  poolcnt                       11096 non-null  float64
#  32  poolsizesum                   867 non-null    float64
#  33  pooltypeid10                  444 non-null    float64
#  34  pooltypeid2                   1071 non-null   float64
#  35  pooltypeid7                   10009 non-null  float64
#  36  propertycountylandusecode     52442 non-null  object
#  37  propertyzoningdesc            33849 non-null  object
#  38  rawcensustractandblock        52442 non-null  float64
#  39  regionidcity                  51405 non-null  float64
#  40  regionidcounty                52442 non-null  float64
#  41  regionidneighborhood          19033 non-null  float64
#  42  regionidzip                   52416 non-null  float64
#  43  roomcnt                       52442 non-null  float64
#  44  threequarterbathnbr           6724 non-null   float64
#  45  unitcnt                       33848 non-null  float64
#  46  yardbuildingsqft17            1937 non-null   float64
#  47  yardbuildingsqft26            63 non-null     float64
#  48  yearbuilt                     52326 non-null  float64
#  49  numberofstories               14561 non-null  float64
#  50  fireplaceflag                 81 non-null     float64
#  51  structuretaxvaluedollarcnt    52358 non-null  float64
#  52  taxvaluedollarcnt             52441 non-null  float64
#  53  assessmentyear                52442 non-null  float64
#  54  landtaxvaluedollarcnt         52441 non-null  float64
#  55  taxamount                     52438 non-null  float64
#  56  taxdelinquencyflag            2079 non-null   object
#  57  taxdelinquencyyear            2079 non-null   float64
#  58  censustractandblock           52319 non-null  float64
#  59  id.1                          52442 non-null  int64
#  60  logerror                      52442 non-null  float64
#  61  transactiondate               52442 non-null  object
#  62  airconditioningdesc           13638 non-null  object
#  63  architecturalstyledesc        70 non-null     object
#  64  buildingclassdesc             0 non-null      float64
#  65  heatingorsystemdesc           33936 non-null  object
#  66  typeconstructiondesc          76 non-null     object
#  67  storydesc                     47 non-null     object
#  68  propertylandusedesc           52442 non-null  object
# dtypes: float64(56), int64(3), object(10)
# memory usage: 27.6+ MB
# None
# --- Descriptions:        propertylandusetypeid      parcelid  storytypeid  \
# count                52442.0  5.244200e+04         47.0
# mean                   261.0  1.299912e+07          7.0
# std                      0.0  3.411412e+06          0.0
# min                    261.0  1.071186e+07          7.0
# 25%                    261.0  1.151030e+07          7.0
# 50%                    261.0  1.257766e+07          7.0
# 75%                    261.0  1.412951e+07          7.0
# max                    261.0  1.676878e+08          7.0
#
#        typeconstructiontypeid  heatingorsystemtypeid  buildingclasstypeid  \
# count               76.000000           33936.000000                  0.0
# mean                 5.973684               3.966378                  NaN
# std                  0.229416               2.562521                  NaN
# min                  4.000000               1.000000                  NaN
# 25%                  6.000000               2.000000                  NaN
# 50%                  6.000000               2.000000                  NaN
# 75%                  6.000000               7.000000                  NaN
# max                  6.000000              24.000000                  NaN
#
#        architecturalstyletypeid  airconditioningtypeid            id  \
# count                  70.00000           13638.000000  5.244200e+04
# mean                    7.10000               2.438041  1.497288e+06
# std                     2.66567               3.846176  8.594413e+05
# min                     2.00000               1.000000  3.490000e+02
# 25%                     7.00000               1.000000  7.579560e+05
# 50%                     7.00000               1.000000  1.500836e+06
# 75%                     7.00000               1.000000  2.241564e+06
# max                    21.00000              13.000000  2.982270e+06
#
#        basementsqft  ...  structuretaxvaluedollarcnt  taxvaluedollarcnt  \
# count     47.000000  ...                5.235800e+04       5.244100e+04
# mean     678.978723  ...                1.965315e+05       5.296830e+05
# std      711.825226  ...                2.543382e+05       7.518883e+05
# min       38.000000  ...                1.290000e+02       1.000000e+03
# 25%      263.500000  ...                7.707175e+04       1.937500e+05
# 50%      512.000000  ...                1.318070e+05       3.736120e+05
# 75%      809.500000  ...                2.263198e+05       6.193010e+05
# max     3560.000000  ...                9.164901e+06       4.906124e+07
#
#        assessmentyear  landtaxvaluedollarcnt      taxamount  \
# count         52442.0           5.244100e+04   52438.000000
# mean           2016.0           3.334626e+05    6453.451945
# std               0.0           5.705227e+05    8755.495483
# min            2016.0           1.610000e+02      49.180000
# 25%            2016.0           7.602600e+04    2656.250000
# 50%            2016.0           2.180250e+05    4647.730000
# 75%            2016.0           4.086000e+05    7377.445000
# max            2016.0           4.895220e+07  586639.300000
#
#        taxdelinquencyyear  censustractandblock          id.1      logerror  \
# count         2079.000000         5.231900e+04  52442.000000  52442.000000
# mean            14.102453         6.050240e+13  38860.631917      0.018294
# std              2.394972         1.859019e+12  22348.437271      0.177502
# min              4.000000         6.037101e+13      0.000000     -4.655420
# 25%             14.000000         6.037401e+13  19546.250000     -0.024639
# 50%             15.000000         6.037620e+13  38927.500000      0.007010
# 75%             15.000000         6.059042e+13  58093.500000      0.040691
# max             99.000000         4.830301e+14  77613.000000      5.262999
#
#        buildingclassdesc
# count                0.0
# mean                 NaN
# std                  NaN
# min                  NaN
# 25%                  NaN
# 50%                  NaN
# 75%                  NaN
# max                  NaN
#
# [8 rows x 59 columns]
# --- Nulls by Column: propertylandusetypeid               0
# parcelid                            0
# storytypeid                     52395
# typeconstructiontypeid          52366
# heatingorsystemtypeid           18506
# buildingclasstypeid             52442
# architecturalstyletypeid        52372
# airconditioningtypeid           38804
# id                                  0
# basementsqft                    52395
# bathroomcnt                         0
# bedroomcnt                          0
# buildingqualitytypeid           18701
# calculatedbathnbr                 137
# decktypeid                      52053
# finishedfloor1squarefeet        48061
# calculatedfinishedsquarefeet       82
# finishedsquarefeet12              247
# finishedsquarefeet13            52442
# finishedsquarefeet15            52442
# finishedsquarefeet50            48061
# finishedsquarefeet6             52277
# fips                                0
# fireplacecnt                    45199
# fullbathcnt                       137
# garagecarcnt                    34427
# garagetotalsqft                 34427
# hashottuborspa                  50927
# latitude                            0
# longitude                           0
# lotsizesquarefeet                 369
# poolcnt                         41346
# poolsizesum                     51575
# pooltypeid10                    51998
# pooltypeid2                     51371
# pooltypeid7                     42433
# propertycountylandusecode           0
# propertyzoningdesc              18593
# rawcensustractandblock              0
# regionidcity                     1037
# regionidcounty                      0
# regionidneighborhood            33409
# regionidzip                        26
# roomcnt                             0
# threequarterbathnbr             45718
# unitcnt                         18594
# yardbuildingsqft17              50505
# yardbuildingsqft26              52379
# yearbuilt                         116
# numberofstories                 37881
# fireplaceflag                   52361
# structuretaxvaluedollarcnt         84
# taxvaluedollarcnt                   1
# assessmentyear                      0
# landtaxvaluedollarcnt               1
# taxamount                           4
# taxdelinquencyflag              50363
# taxdelinquencyyear              50363
# censustractandblock               123
# id.1                                0
# logerror                            0
# transactiondate                     0
# airconditioningdesc             38804
# architecturalstyledesc          52372
# buildingclassdesc               52442
# heatingorsystemdesc             18506
# typeconstructiondesc            52366
# storydesc                       52395
# propertylandusedesc                 0
# dtype: int64
# nulls by row: n_missing  percent_missing
# 23         0.333333               2
# 24         0.347826              12
# 25         0.362319              11
# 26         0.376812              30
# 27         0.391304             177
# 28         0.405797             392
# 29         0.420290            2531
# 30         0.434783            2204
# 31         0.449275            6004
# 32         0.463768            8901
# 33         0.478261           11997
# 34         0.492754           11182
# 35         0.507246            3478
# 36         0.521739            4147
# 37         0.536232            1023
# 38         0.550725             227
# 39         0.565217              29
# 40         0.579710              15
# 41         0.594203               6
# 42         0.608696               7
# 43         0.623188              10
# 44         0.637681              47
# 45         0.652174               6
# 46         0.666667               1
# 47         0.681159               1
# 48         0.695652               2
# dtype: int64
# None None None None None None

# %% [markdown]
# ## 3) Write a function that takes in a dataframe of observations and attributes and returns a dataframe where each row is an atttribute name, the first column is the number of rows with missing values for that attribute, and the second column is percent of total rows that have missing values for that attribute. Run the function and document takeaways from this on how you want to handle missing values.

# %%
wrangle_zillow.nulls_by_columns(df).sort_values(by= 'percent', ascending=False)
# Out:
#                               count   percent
# finishedsquarefeet15          52442  1.000000
# buildingclasstypeid           52442  1.000000
# buildingclassdesc             52442  1.000000
# finishedsquarefeet13          52442  1.000000
# storydesc                     52395  0.999104
# basementsqft                  52395  0.999104
# storytypeid                   52395  0.999104
# yardbuildingsqft26            52379  0.998799
# architecturalstyletypeid      52372  0.998665
# architecturalstyledesc        52372  0.998665
# typeconstructiontypeid        52366  0.998551
# typeconstructiondesc          52366  0.998551
# fireplaceflag                 52361  0.998455
# finishedsquarefeet6           52277  0.996854
# decktypeid                    52053  0.992582
# pooltypeid10                  51998  0.991534
# poolsizesum                   51575  0.983467
# pooltypeid2                   51371  0.979577
# hashottuborspa                50927  0.971111
# yardbuildingsqft17            50505  0.963064
# taxdelinquencyyear            50363  0.960356
# taxdelinquencyflag            50363  0.960356
# finishedsquarefeet50          48061  0.916460
# finishedfloor1squarefeet      48061  0.916460
# threequarterbathnbr           45718  0.871782
# fireplacecnt                  45199  0.861886
# pooltypeid7                   42433  0.809142
# poolcnt                       41346  0.788414
# airconditioningtypeid         38804  0.739941
# airconditioningdesc           38804  0.739941
# numberofstories               37881  0.722341
# garagetotalsqft               34427  0.656478
# garagecarcnt                  34427  0.656478
# regionidneighborhood          33409  0.637066
# buildingqualitytypeid         18701  0.356603
# unitcnt                       18594  0.354563
# propertyzoningdesc            18593  0.354544
# heatingorsystemdesc           18506  0.352885
# heatingorsystemtypeid         18506  0.352885
# regionidcity                   1037  0.019774
# lotsizesquarefeet               369  0.007036
# finishedsquarefeet12            247  0.004710
# calculatedbathnbr               137  0.002612
# fullbathcnt                     137  0.002612
# censustractandblock             123  0.002345
# yearbuilt                       116  0.002212
# structuretaxvaluedollarcnt       84  0.001602
# calculatedfinishedsquarefeet     82  0.001564
# regionidzip                      26  0.000496
# taxamount                         4  0.000076
# taxvaluedollarcnt                 1  0.000019
# landtaxvaluedollarcnt             1  0.000019
# id.1                              0  0.000000
# logerror                          0  0.000000
# transactiondate                   0  0.000000
# propertylandusetypeid             0  0.000000
# assessmentyear                    0  0.000000
# roomcnt                           0  0.000000
# regionidcounty                    0  0.000000
# rawcensustractandblock            0  0.000000
# propertycountylandusecode         0  0.000000
# parcelid                          0  0.000000
# longitude                         0  0.000000
# latitude                          0  0.000000
# fips                              0  0.000000
# bedroomcnt                        0  0.000000
# bathroomcnt                       0  0.000000
# id                                0  0.000000
# propertylandusedesc               0  0.000000

# %% [markdown]
# - there is a huge leap from 35% to 63% missing values
# - this information will allow me to focus on a number like 50% to make the threshhold of missing data, anyhting after that will be deleted.

# %% [markdown]
# ### Prepare
#
# 1) Remove any properties that are likely to be something other than single unit properties. (e.g. no duplexes, no land/lot, ...). There are multiple ways to estimate that a property is a single unit, and there is not a single "right" answer.
#
# Create a function that will drop rows or columns based on the percent of values that are missing: handle_missing_values(df, prop_required_column, prop_required_row).
#
# - The input:
#   - A dataframe
#   - A number between 0 and 1 that represents the proportion, for each column, of rows with non-missing values required to keep the column. i.e. if prop_required_column = .6, then you are requiring a column to have at least 60% of values not-NA (no more than 40% missing).
#   - A number between 0 and 1 that represents the proportion, for each row, of columns/variables with non-missing values required to keep the row. For example, if prop_required_row = .75, then you are requiring a row to have at least 75% of variables with a non-missing value (no more that 25% missing).
# - The output:
#   - The dataframe with the columns and rows dropped as indicated. Be sure to drop the columns prior to the rows in your function.
# - hint:
#   - Look up the dropna documentation.
#   - You will want to compute a threshold from your input values (prop_required) and total number of rows or columns.
# 3) Encapsulate your work inside of functions in a wrangle_zillow.py module.

# %%
print('Before dropping nulls, %d rows ,%d cols' % df.shape)
df = wrangle_zillow.handle_missing_value(df, prop_required_column=.5, prop_required_row=.5)
print('After dropping nulls, %d rows ,%d cols' % df.shape)
# Out:
# Before dropping nulls, 52442 rows ,69 cols
# After dropping nulls, 46921 rows ,35 cols

# %% [markdown]
# ***
